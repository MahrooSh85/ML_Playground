# %%
import numpy as np
import pandas as pd

# %matplotlib notebook

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
# create a new figure
plt.figure()





# get the current axes
ax = plt.gca()

ax.axis([xmin,xmax,ymin,ymax])

# %% [markdown]
# # Scatterplot

# %%
x = np.array([1,2,3,4,5,6,7,8])
y = x

plt.figure(figsize = (2, 2))
plt.scatter(x, y, c ="pink",
            linewidths = 2,
            marker ="s",
            edgecolor ="green",
            s = 50)
# similar to plt.plot(x, y, '.'), but the underlying child objects in the axes are not Line2D
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
plt.figure(figsize=(2,2))
plt.plot(x, y, '.')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend( ["title_1", "Title_2"],  ncol = 1 , loc = "upper left" ,bbox_to_anchor =(1, 1))
plt.title("Connected Scatterplot points with lines")
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %% [markdown]
# # Bar plot

# %%
plt.bar(x, height, width, bottom, align)

# %% [markdown]
# # Pie chart

# %%
plt.figure(figsize=(3,3))
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]

plt.pie(sizes, labels=labels)
# Out:
# <img src="data:image/png;base64,..." width="300">
# ([<matplotlib.patches.Wedge at 0x117c731d0>,
#   <matplotlib.patches.Wedge at 0x117c73790>,
#   <matplotlib.patches.Wedge at 0x117c73cd0>,
#   <matplotlib.patches.Wedge at 0x11799c290>],
#  [Text(0.730677650908226, 0.8222591869132486, 'Python'),
#   Text(-0.6465638275138399, 0.8899186574910392, 'C++'),
#   Text(-0.9490077933291499, -0.5562231640272972, 'Ruby'),
#   Text(0.7466808503372186, -0.8077547324155323, 'Java')])

# %% [markdown]
# # Histogram plot
